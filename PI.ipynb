# %% [markdown]
# import pandas as pd

# %%
df1=pd.read_csv(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\lap_times\lap_times_split_1.csv')

# %%
df1.head()
# Out:
#    841  20  1  1.1  1:38.109  98109
# 0  841  20  2    1  1:33.006  93006
# 1  841  20  3    1  1:32.713  92713
# 2  841  20  4    1  1:32.803  92803
# 3  841  20  5    1  1:32.342  92342
# 4  841  20  6    1  1:32.605  92605

# %%
df1.columns=['raceId','driverId','lap','position','time','miliseconds']

# %%
df1.head()
# Out:
#    raceId  driverId  lap  position      time  miliseconds
# 0     841        20    2         1  1:33.006        93006
# 1     841        20    3         1  1:32.713        92713
# 2     841        20    4         1  1:32.803        92803
# 3     841        20    5         1  1:32.342        92342
# 4     841        20    6         1  1:32.605        92605

# %%
df2=pd.read_json(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\Qualifying\qualifying_split_1.json')

# %%
df2.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
df3=pd.read_json(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\Qualifying\qualifying_split_2.json')

# %%
df3.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0       5002     861       811              3      19        13  1:38.437
# 1       5003     861       814             10      11        14  1:38.325
# 2       5004     861       817              5      16        15  1:38.419
# 3       5005     861       807             10      12        16  1:38.303
# 4       5006     861       155             15      14        17  1:38.372
#
#          q2  q3
# 0  1:37.841  \N
# 1  1:37.877  \N
# 2  1:37.883  \N
# 3  1:37.890  \N
# 4  1:38.069  \N

# %%
df4=pd.read_csv(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\circuits.csv')

# %%
df4.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt  \
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...

# %%
df5=pd.read_json(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\constructors.json', lines=True)

# %%
df5.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
df6=pd.read_json(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\drivers.json', lines=True)

# %%
df6.head()
# Out:
#    driverId   driverRef number code  \
# 0         1    hamilton     44  HAM
# 1         2    heidfeld     \N  HEI
# 2         3     rosberg      6  ROS
# 3         4      alonso     14  ALO
# 4         5  kovalainen     \N  KOV
#
#                                               name         dob nationality  \
# 0     {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1      {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
# 2       {'forename': 'Nico', 'surname': 'Rosberg'}  1985-06-27      German
# 3    {'forename': 'Fernando', 'surname': 'Alonso'}  1981-07-29     Spanish
# 4  {'forename': 'Heikki', 'surname': 'Kovalainen'}  1981-10-19     Finnish
#
#                                               url
# 0     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3    http://en.wikipedia.org/wiki/Fernando_Alonso
# ...

# %%
drivers_df6 = pd.concat([df6.drop(['name'], axis=1), df6['name'].apply(pd.Series)], axis=1)

# %%
drivers_df6.head()
# Out:
#    driverId   driverRef number code         dob nationality  \
# 0         1    hamilton     44  HAM  1985-01-07     British
# 1         2    heidfeld     \N  HEI  1977-05-10      German
# 2         3     rosberg      6  ROS  1985-06-27      German
# 3         4      alonso     14  ALO  1981-07-29     Spanish
# 4         5  kovalainen     \N  KOV  1981-10-19     Finnish
#
#                                               url  forename     surname
# 0     http://en.wikipedia.org/wiki/Lewis_Hamilton     Lewis    Hamilton
# 1      http://en.wikipedia.org/wiki/Nick_Heidfeld      Nick    Heidfeld
# 2       http://en.wikipedia.org/wiki/Nico_Rosberg      Nico     Rosberg
# 3    http://en.wikipedia.org/wiki/Fernando_Alonso  Fernando      Alonso
# 4  http://en.wikipedia.org/wiki/Heikki_Kovalainen    Heikki  Kovalainen

# %%
df7=pd.read_json(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\pit_stops.json')

# %%
df7.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
df8=pd.read_csv(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\races.csv')

# %%
df8.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
df9=pd.read_json(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\results.json', lines=True)

# %%
df9.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452           218.3         1
# ...

# %%
df10=pd.read_csv(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\lap_times\lap_times_split_2.csv')

# %%
df10.head()
# Out:
#    933  830  47  7  1:12.976  72976
# 0  933  830  48  7  1:13.108  73108
# 1  933  830  49  7  1:12.972  72972
# 2  933  830  50  7  1:12.767  72767
# 3  933  830  51  7  1:13.248  73248
# 4  933  830  52  7  1:12.829  72829

# %%
df10.columns=['raceId','driverId','lap','position','time','miliseconds']

# %%
df10.head()
# Out:
#    raceId  driverId  lap  position      time  miliseconds
# 0     933       830   48         7  1:13.108        73108
# 1     933       830   49         7  1:12.972        72972
# 2     933       830   50         7  1:12.767        72767
# 3     933       830   51         7  1:13.248        73248
# 4     933       830   52         7  1:12.829        72829

# %%
df11=pd.read_csv(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\lap_times\lap_times_split_3.csv')

# %%
df11.head()
# Out:
#    145  2  39   7  1:27.597   87597
# 0  145  2  40  10  1:47.283  107283
# 1  145  2  41  10  1:25.187   85187
# 2  145  2  42  10  1:23.978   83978
# 3  145  2  43  10  1:24.152   84152
# 4  145  2  44   9  1:24.952   84952

# %%
df11.columns=['raceId','driverId','lap','position','time','miliseconds']

# %%
df11.head()
# Out:
#    raceId  driverId  lap  position      time  miliseconds
# 0     145         2   40        10  1:47.283       107283
# 1     145         2   41        10  1:25.187        85187
# 2     145         2   42        10  1:23.978        83978
# 3     145         2   43        10  1:24.152        84152
# 4     145         2   44         9  1:24.952        84952

# %%
df12=pd.read_csv(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\lap_times\lap_times_split_4.csv')

# %%
df12.head()
# Out:
#    67  14  26  13  1:25.802  85802
# 0  67  14  27  13  1:25.338  85338
# 1  67  14  28  13  1:25.395  85395
# 2  67  14  29  12  1:26.191  86191
# 3  67  14  30  11  1:25.439  85439
# 4  67  14  31  10  1:25.375  85375

# %%
df12.columns=['raceId','driverId','lap','position','time','miliseconds']

# %%
df12.head()
# Out:
#    raceId  driverId  lap  position      time  miliseconds
# 0      67        14   27        13  1:25.338        85338
# 1      67        14   28        13  1:25.395        85395
# 2      67        14   29        12  1:26.191        86191
# 3      67        14   30        11  1:25.439        85439
# 4      67        14   31        10  1:25.375        85375

# %%
df13=pd.read_csv(r'C:\Users\pia_r\Documents\SOY HENRY\DATA SCIENCE MATERIAL COMPLETO\Proyecto Individual 1\PI01_DATA03\Datasets\lap_times\lap_times_split_5.csv')

# %%
df13.columns=['raceId','driverId','lap','position','time','miliseconds']

# %%
df13.head()
# Out:
#    raceId  driverId  lap  position      time  miliseconds
# 0     963       836   10        17  2:17.112       137112
# 1     963       836   11        17  1:44.058       104058
# 2     963       836   12        17  1:43.085       103085
# 3     963       836   13        16  1:42.988       102988
# 4     963       836   14        16  1:43.222       103222

# %%
df1.to_csv('lap_times_split_1.csv')

# %%
df2.to_csv('qualifying_split_1.csv')

# %%
df3.to_csv('qualifying_split_2.csv')

# %%
df4.to_csv('circuits.csv')

# %%
df5.to_csv('constructors.csv')

# %%
drivers_df6.to_csv('drivers.csv')

# %%
df7.to_csv('pit_stops.csv')

# %%
df8.to_csv('races.csv')

# %%
df9.to_csv('results.csv')

# %%
df10.to_csv('lap_times_split_2.csv')

# %%
df11.to_csv('lap_times_split_3.csv')

# %%
df12.to_csv('lap_times_split_4.csv')

# %%
df13.to_csv('lap_times_split_5.csv')
